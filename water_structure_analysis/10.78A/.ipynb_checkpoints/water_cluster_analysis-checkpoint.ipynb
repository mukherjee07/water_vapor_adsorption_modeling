# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
import os

# Function to read the combined XYZ file and extract water molecule positions
def read_combined_xyz(input_file):
    water_positions = {'O': [], 'H': []}

    with open(input_file, 'r') as file:
        lines = file.readlines()

    for line in lines[2:]:  # Skip the first two lines (atom count and comment)
        parts = line.split()
        atom_type = parts[0]
        x, y, z = map(float, parts[1:4])

        # Classify based on atom type
        if atom_type == 'O':
            water_positions['O'].append((x, y, z))
        elif atom_type == 'H':
            water_positions['H'].append((x, y, z))

    return water_positions

# Function to cluster water molecules into layers based on z-coordinate
def cluster_water_layers(water_positions, layer_thickness=2.0):
    positions = water_positions['O']
    z_coords = np.array([pos[2] for pos in positions])
    positions = np.array(positions)

    # Sort positions based on z-coordinate
    sorted_indices = np.argsort(z_coords)
    sorted_positions = positions[sorted_indices]

    # Initialize layers
    layers = []
    current_layer = [sorted_positions[0]]

    # Cluster molecules into layers based on z-coordinate differences
    for pos in sorted_positions[1:]:
        if abs(pos[2] - current_layer[0][2]) <= layer_thickness:
            current_layer.append(pos)
        else:
            layers.append(current_layer)
            current_layer = [pos]

    # Add the last layer
    if current_layer:
        layers.append(current_layer)

    return layers

# Function to calculate average z-location, standard deviation, and average inter-layer distance
def calculate_layer_properties(layers, min_molecules=4):
    # Filter out layers with fewer than 'min_molecules' water molecules
    filtered_layers = [layer for layer in layers if len(layer) >= min_molecules]

    if not filtered_layers:
        return [], [], 0, 0, []  # No valid layers after filtering

    avg_z_locations = []
    std_devs = []
    com_positions = []
    for layer in filtered_layers:
        z_coords = [pos[2] for pos in layer]
        avg_z = np.mean(z_coords)
        std_dev = np.std(z_coords)
        avg_z_locations.append(avg_z)
        std_devs.append(std_dev)
        # Compute COM for the layer
        com = np.mean(layer, axis=0)
        com_positions.append(com)

    # Calculate average inter-layer distance
    if len(avg_z_locations) > 1:
        avg_distances = [abs(avg_z_locations[i] - avg_z_locations[i-1]) for i in range(1, len(avg_z_locations))]
        avg_inter_layer_distance = np.mean(avg_distances)
    else:
        avg_inter_layer_distance = 0  # Only one valid layer, so no inter-layer distance

    # Calculate average of standard deviations across valid layers
    avg_std_dev_across_layers = np.mean(std_devs)

    return avg_z_locations, std_devs, avg_inter_layer_distance, avg_std_dev_across_layers, filtered_layers, com_positions

# Function to analyze layers and compute COM and distances
def analyze_layers(layers):
    all_distances = []
    for i, layer in enumerate(layers):
        positions = np.array(layer)
        # Compute COM by averaging positions
        com = np.mean(positions, axis=0)
        print(f"Layer {i+1} center of mass: x={com[0]:.3f}, y={com[1]:.3f}, z={com[2]:.3f}")
        # Compute distances of each oxygen atom to the COM
        distances = np.linalg.norm(positions - com, axis=1)
        # Compute mean distance from center
        mean_distance = np.mean(distances)
        print(f"Layer {i+1} mean distance from center: {mean_distance:.3f} Å")
        # Collect distances for PDF
        all_distances.extend(distances)

    return all_distances

# Function to analyze distances between layer COMs
def analyze_layer_com_distances(com_positions):
    com_positions = np.array(com_positions)
    com_distances = []
    for i in range(len(com_positions) - 1):
        # Compute distance between COMs of adjacent layers
        distance = np.linalg.norm(com_positions[i+1] - com_positions[i])
        com_distances.append(distance)

    # Print distances
    for i, distance in enumerate(com_distances):
        print(f"Distance between Layer {i+1} and Layer {i+2} COMs: {distance:.3f} Å")

    return com_distances

# List of configurations and their corresponding min_molecules
configurations = {
    'AA': 3,
    'AR': 3,
    'AAR': 3,
    'Inner': 3,
    'Outer': 3
}

# Initialize dictionaries to store data for plotting
oxygen_com_distances_data = {}
layer_com_distances_data = {}

for config, min_molecules in configurations.items():
    folder = config
    input_file = os.path.join(folder, 'combined_structure.xyz')
    if not os.path.isfile(input_file):
        print(f"File {input_file} not found. Skipping configuration {config}.")
        continue

    print(f"\nProcessing configuration: {config}")
    # Read the combined XYZ file
    water_positions = read_combined_xyz(input_file)

    # Cluster water molecules into layers
    layers = cluster_water_layers(water_positions)

    # Calculate average z-location, standard deviation, and average inter-layer distance
    avg_z_locations, std_devs, avg_inter_layer_distance, avg_std_dev_across_layers, filtered_layers, com_positions = calculate_layer_properties(layers, min_molecules=min_molecules)

    # Output results
    if avg_z_locations:
        print(f"Total number of water layers with at least {min_molecules} molecules: {len(avg_z_locations)}")
        for i, (avg_z, std_dev) in enumerate(zip(avg_z_locations, std_devs), 1):
            print(f"Layer {i}: Average z-location = {avg_z:.3f} Å, Standard deviation = {std_dev:.3f} Å")

        if avg_inter_layer_distance > 0:
            print(f"Average distance between layers in the z-direction: {avg_inter_layer_distance:.3f} Å")
        else:
            print("Only one valid water layer detected, no inter-layer distance calculated.")

        print(f"Average standard deviation of z-direction within valid layers: {avg_std_dev_across_layers:.3f} Å")

        # Analyze layers for COM and distances
        oxygen_com_distances = analyze_layers(filtered_layers)
        oxygen_com_distances_data[config] = oxygen_com_distances

        # Analyze distances between layer COMs
        layer_com_distances = analyze_layer_com_distances(com_positions)
        layer_com_distances_data[config] = layer_com_distances
    else:
        print(f"No water layers with at least {min_molecules} molecules were found in configuration {config}.")
# Out:
# Processing configuration: AA
# Total number of water layers with at least 3 molecules: 11
# Layer 1: Average z-location = 1.343 Å, Standard deviation = 0.037 Å
# Layer 2: Average z-location = 4.147 Å, Standard deviation = 0.351 Å
# Layer 3: Average z-location = 7.029 Å, Standard deviation = 0.390 Å
# Layer 4: Average z-location = 10.046 Å, Standard deviation = 0.390 Å
# Layer 5: Average z-location = 13.101 Å, Standard deviation = 0.381 Å
# Layer 6: Average z-location = 16.309 Å, Standard deviation = 0.368 Å
# Layer 7: Average z-location = 19.178 Å, Standard deviation = 0.424 Å
# Layer 8: Average z-location = 22.247 Å, Standard deviation = 0.684 Å
# Layer 9: Average z-location = 24.768 Å, Standard deviation = 0.865 Å
# Layer 10: Average z-location = 26.034 Å, Standard deviation = 0.159 Å
# Layer 11: Average z-location = 28.762 Å, Standard deviation = 0.435 Å
# Average distance between layers in the z-direction: 2.742 Å
# Average standard deviation of z-direction within valid layers: 0.408 Å
# Layer 1 center of mass: x=15.159, y=15.664, z=1.343
# Layer 1 mean distance from center: 2.202 Å
# Layer 2 center of mass: x=15.563, y=15.478, z=4.147
# Layer 2 mean distance from center: 2.337 Å
# Layer 3 center of mass: x=15.445, y=15.505, z=7.029
# Layer 3 mean distance from center: 2.285 Å
# Layer 4 center of mass: x=15.260, y=15.445, z=10.046
# Layer 4 mean distance from center: 2.326 Å
# Layer 5 center of mass: x=15.369, y=15.233, z=13.101
# Layer 5 mean distance from center: 2.313 Å
# Layer 6 center of mass: x=15.521, y=15.347, z=16.309
# Layer 6 mean distance from center: 2.320 Å
# Layer 7 center of mass: x=15.421, y=15.427, z=19.178
# Layer 7 mean distance from center: 2.321 Å
# Layer 8 center of mass: x=15.534, y=15.534, z=22.247
# Layer 8 mean distance from center: 2.451 Å
# Layer 9 center of mass: x=14.860, y=15.261, z=24.768
# Layer 9 mean distance from center: 2.138 Å
# Layer 10 center of mass: x=15.297, y=15.715, z=26.034
# Layer 10 mean distance from center: 2.300 Å
# Layer 11 center of mass: x=15.346, y=14.714, z=28.762
# Layer 11 mean distance from center: 2.230 Å
# Distance between Layer 1 and Layer 2 COMs: 2.839 Å
# Distance between Layer 2 and Layer 3 COMs: 2.884 Å
# Distance between Layer 3 and Layer 4 COMs: 3.024 Å
# Distance between Layer 4 and Layer 5 COMs: 3.064 Å
# Distance between Layer 5 and Layer 6 COMs: 3.213 Å
# Distance between Layer 6 and Layer 7 COMs: 2.872 Å
# Distance between Layer 7 and Layer 8 COMs: 3.073 Å
# Distance between Layer 8 and Layer 9 COMs: 2.624 Å
# Distance between Layer 9 and Layer 10 COMs: 1.414 Å
# Distance between Layer 10 and Layer 11 COMs: 2.907 Å
#
# Processing configuration: AR
# Total number of water layers with at least 3 molecules: 10
# Layer 1: Average z-location = 0.088 Å, Standard deviation = 0.355 Å
# Layer 2: Average z-location = 2.852 Å, Standard deviation = 0.276 Å
# Layer 3: Average z-location = 5.929 Å, Standard deviation = 0.416 Å
# Layer 4: Average z-location = 8.698 Å, Standard deviation = 0.293 Å
# Layer 5: Average z-location = 11.469 Å, Standard deviation = 0.257 Å
# Layer 6: Average z-location = 14.205 Å, Standard deviation = 0.186 Å
# Layer 7: Average z-location = 16.946 Å, Standard deviation = 0.287 Å
# Layer 8: Average z-location = 19.672 Å, Standard deviation = 0.211 Å
# Layer 9: Average z-location = 22.528 Å, Standard deviation = 0.263 Å
# Layer 10: Average z-location = 25.272 Å, Standard deviation = 0.396 Å
# Average distance between layers in the z-direction: 2.798 Å
# Average standard deviation of z-direction within valid layers: 0.294 Å
# Layer 1 center of mass: x=15.161, y=16.360, z=0.088
# Layer 1 mean distance from center: 1.788 Å
# Layer 2 center of mass: x=15.398, y=15.373, z=2.852
# Layer 2 mean distance from center: 2.046 Å
# Layer 3 center of mass: x=15.479, y=15.267, z=5.929
# Layer 3 mean distance from center: 2.244 Å
# Layer 4 center of mass: x=15.557, y=15.805, z=8.698
# Layer 4 mean distance from center: 2.011 Å
# Layer 5 center of mass: x=15.442, y=15.361, z=11.469
# Layer 5 mean distance from center: 1.930 Å
# Layer 6 center of mass: x=15.605, y=15.082, z=14.205
# Layer 6 mean distance from center: 1.976 Å
# Layer 7 center of mass: x=15.441, y=15.484, z=16.946
# Layer 7 mean distance from center: 1.991 Å
# Layer 8 center of mass: x=15.493, y=15.538, z=19.672
# Layer 8 mean distance from center: 1.981 Å
# Layer 9 center of mass: x=15.435, y=15.539, z=22.528
# Layer 9 mean distance from center: 1.867 Å
# Layer 10 center of mass: x=14.873, y=15.907, z=25.272
# Layer 10 mean distance from center: 1.909 Å
# Distance between Layer 1 and Layer 2 COMs: 2.944 Å
# Distance between Layer 2 and Layer 3 COMs: 3.080 Å
# Distance between Layer 3 and Layer 4 COMs: 2.822 Å
# Distance between Layer 4 and Layer 5 COMs: 2.809 Å
# Distance between Layer 5 and Layer 6 COMs: 2.755 Å
# Distance between Layer 6 and Layer 7 COMs: 2.775 Å
# Distance between Layer 7 and Layer 8 COMs: 2.727 Å
# Distance between Layer 8 and Layer 9 COMs: 2.857 Å
# Distance between Layer 9 and Layer 10 COMs: 2.825 Å
#
# Processing configuration: AAR
# Total number of water layers with at least 3 molecules: 10
# Layer 1: Average z-location = 7.970 Å, Standard deviation = 0.347 Å
# Layer 2: Average z-location = 10.784 Å, Standard deviation = 0.259 Å
# Layer 3: Average z-location = 13.739 Å, Standard deviation = 0.139 Å
# Layer 4: Average z-location = 16.535 Å, Standard deviation = 0.083 Å
# Layer 5: Average z-location = 19.277 Å, Standard deviation = 0.145 Å
# Layer 6: Average z-location = 22.100 Å, Standard deviation = 0.146 Å
# Layer 7: Average z-location = 24.883 Å, Standard deviation = 0.202 Å
# Layer 8: Average z-location = 27.650 Å, Standard deviation = 0.059 Å
# Layer 9: Average z-location = 30.425 Å, Standard deviation = 0.122 Å
# Layer 10: Average z-location = 33.182 Å, Standard deviation = 0.186 Å
# Average distance between layers in the z-direction: 2.801 Å
# Average standard deviation of z-direction within valid layers: 0.169 Å
# Layer 1 center of mass: x=15.264, y=15.523, z=7.970
# Layer 1 mean distance from center: 2.175 Å
# Layer 2 center of mass: x=15.345, y=15.283, z=10.784
# Layer 2 mean distance from center: 2.092 Å
# Layer 3 center of mass: x=15.451, y=15.157, z=13.739
# Layer 3 mean distance from center: 1.942 Å
# Layer 4 center of mass: x=15.597, y=15.288, z=16.535
# Layer 4 mean distance from center: 1.978 Å
# Layer 5 center of mass: x=15.321, y=15.696, z=19.277
# Layer 5 mean distance from center: 1.976 Å
# Layer 6 center of mass: x=15.302, y=15.456, z=22.100
# Layer 6 mean distance from center: 1.987 Å
# Layer 7 center of mass: x=15.305, y=15.715, z=24.883
# Layer 7 mean distance from center: 1.945 Å
# Layer 8 center of mass: x=15.362, y=15.458, z=27.650
# Layer 8 mean distance from center: 1.945 Å
# Layer 9 center of mass: x=15.492, y=15.538, z=30.425
# Layer 9 mean distance from center: 1.951 Å
# Layer 10 center of mass: x=15.279, y=15.112, z=33.182
# Layer 10 mean distance from center: 1.973 Å
# Distance between Layer 1 and Layer 2 COMs: 2.825 Å
# Distance between Layer 2 and Layer 3 COMs: 2.960 Å
# Distance between Layer 3 and Layer 4 COMs: 2.803 Å
# Distance between Layer 4 and Layer 5 COMs: 2.786 Å
# Distance between Layer 5 and Layer 6 COMs: 2.834 Å
# Distance between Layer 6 and Layer 7 COMs: 2.794 Å
# Distance between Layer 7 and Layer 8 COMs: 2.780 Å
# Distance between Layer 8 and Layer 9 COMs: 2.779 Å
# Distance between Layer 9 and Layer 10 COMs: 2.798 Å
#
# Processing configuration: Inner
# Total number of water layers with at least 3 molecules: 11
# Layer 1: Average z-location = 0.899 Å, Standard deviation = 0.228 Å
# Layer 2: Average z-location = 3.083 Å, Standard deviation = 0.216 Å
# Layer 3: Average z-location = 5.792 Å, Standard deviation = 0.273 Å
# Layer 4: Average z-location = 8.871 Å, Standard deviation = 0.334 Å
# Layer 5: Average z-location = 11.764 Å, Standard deviation = 0.121 Å
# Layer 6: Average z-location = 14.588 Å, Standard deviation = 0.267 Å
# Layer 7: Average z-location = 17.450 Å, Standard deviation = 0.154 Å
# Layer 8: Average z-location = 20.351 Å, Standard deviation = 0.194 Å
# Layer 9: Average z-location = 23.297 Å, Standard deviation = 0.115 Å
# Layer 10: Average z-location = 26.107 Å, Standard deviation = 0.213 Å
# Layer 11: Average z-location = 28.794 Å, Standard deviation = 0.285 Å
# Average distance between layers in the z-direction: 2.789 Å
# Average standard deviation of z-direction within valid layers: 0.218 Å
# Layer 1 center of mass: x=16.086, y=14.853, z=0.899
# Layer 1 mean distance from center: 2.164 Å
# Layer 2 center of mass: x=15.389, y=15.436, z=3.083
# Layer 2 mean distance from center: 1.888 Å
# Layer 3 center of mass: x=15.571, y=15.197, z=5.792
# Layer 3 mean distance from center: 1.826 Å
# Layer 4 center of mass: x=15.455, y=15.046, z=8.871
# Layer 4 mean distance from center: 1.935 Å
# Layer 5 center of mass: x=15.196, y=15.635, z=11.764
# Layer 5 mean distance from center: 1.921 Å
# Layer 6 center of mass: x=15.544, y=15.434, z=14.588
# Layer 6 mean distance from center: 1.951 Å
# Layer 7 center of mass: x=15.360, y=15.343, z=17.450
# Layer 7 mean distance from center: 2.073 Å
# Layer 8 center of mass: x=15.441, y=15.402, z=20.351
# Layer 8 mean distance from center: 2.066 Å
# Layer 9 center of mass: x=15.393, y=15.401, z=23.297
# Layer 9 mean distance from center: 1.978 Å
# Layer 10 center of mass: x=15.573, y=15.499, z=26.107
# Layer 10 mean distance from center: 1.998 Å
# Layer 11 center of mass: x=15.444, y=15.767, z=28.794
# Layer 11 mean distance from center: 2.047 Å
# Distance between Layer 1 and Layer 2 COMs: 2.366 Å
# Distance between Layer 2 and Layer 3 COMs: 2.725 Å
# Distance between Layer 3 and Layer 4 COMs: 3.085 Å
# Distance between Layer 4 and Layer 5 COMs: 2.963 Å
# Distance between Layer 5 and Layer 6 COMs: 2.853 Å
# Distance between Layer 6 and Layer 7 COMs: 2.869 Å
# Distance between Layer 7 and Layer 8 COMs: 2.903 Å
# Distance between Layer 8 and Layer 9 COMs: 2.947 Å
# Distance between Layer 9 and Layer 10 COMs: 2.817 Å
# Distance between Layer 10 and Layer 11 COMs: 2.704 Å
#
# Processing configuration: Outer
# Total number of water layers with at least 3 molecules: 11
# Layer 1: Average z-location = -1.354 Å, Standard deviation = 0.230 Å
# Layer 2: Average z-location = 1.236 Å, Standard deviation = 0.248 Å
# Layer 3: Average z-location = 4.041 Å, Standard deviation = 0.253 Å
# Layer 4: Average z-location = 6.805 Å, Standard deviation = 0.252 Å
# Layer 5: Average z-location = 9.721 Å, Standard deviation = 0.203 Å
# Layer 6: Average z-location = 12.436 Å, Standard deviation = 0.093 Å
# Layer 7: Average z-location = 15.315 Å, Standard deviation = 0.230 Å
# Layer 8: Average z-location = 18.164 Å, Standard deviation = 0.210 Å
# Layer 9: Average z-location = 20.989 Å, Standard deviation = 0.340 Å
# Layer 10: Average z-location = 23.676 Å, Standard deviation = 0.295 Å
# Layer 11: Average z-location = 26.466 Å, Standard deviation = 0.283 Å
# Average distance between layers in the z-direction: 2.782 Å
# Average standard deviation of z-direction within valid layers: 0.240 Å
# Layer 1 center of mass: x=14.871, y=14.947, z=-1.354
# Layer 1 mean distance from center: 1.927 Å
# Layer 2 center of mass: x=15.043, y=15.331, z=1.236
# Layer 2 mean distance from center: 1.902 Å
# Layer 3 center of mass: x=15.255, y=15.192, z=4.041
# Layer 3 mean distance from center: 2.043 Å
# Layer 4 center of mass: x=15.101, y=15.391, z=6.805
# Layer 4 mean distance from center: 1.966 Å
# Layer 5 center of mass: x=15.366, y=15.317, z=9.721
# Layer 5 mean distance from center: 1.934 Å
# Layer 6 center of mass: x=15.541, y=15.404, z=12.436
# Layer 6 mean distance from center: 2.024 Å
# Layer 7 center of mass: x=15.752, y=15.500, z=15.315
# Layer 7 mean distance from center: 2.051 Å
# Layer 8 center of mass: x=15.463, y=15.399, z=18.164
# Layer 8 mean distance from center: 1.937 Å
# Layer 9 center of mass: x=15.580, y=15.497, z=20.989
# Layer 9 mean distance from center: 2.068 Å
# Layer 10 center of mass: x=15.286, y=15.415, z=23.676
# Layer 10 mean distance from center: 2.314 Å
# Layer 11 center of mass: x=15.077, y=15.974, z=26.466
# Layer 11 mean distance from center: 1.928 Å
# Distance between Layer 1 and Layer 2 COMs: 2.624 Å
# Distance between Layer 2 and Layer 3 COMs: 2.817 Å
# Distance between Layer 3 and Layer 4 COMs: 2.775 Å
# Distance between Layer 4 and Layer 5 COMs: 2.929 Å
# Distance between Layer 5 and Layer 6 COMs: 2.722 Å
# Distance between Layer 6 and Layer 7 COMs: 2.888 Å
# Distance between Layer 7 and Layer 8 COMs: 2.865 Å
# Distance between Layer 8 and Layer 9 COMs: 2.829 Å
# Distance between Layer 9 and Layer 10 COMs: 2.705 Å
# Distance between Layer 10 and Layer 11 COMs: 2.853 Å

# %%
# Plotting Oxygen-COM Distance Probability Functions for all configurations
plt.figure(dpi=800)
colors = ['orange', 'cyan', 'green', 'red', 'silver']
c = 0
for i, (config, distances) in enumerate(oxygen_com_distances_data.items()):
    if distances:
        distances = np.array(distances)
        # Compute probability density
        # Compute probability density
        desired_bandwidth = 1/8

        # Custom bandwidth method
        def fixed_bandwidth_method(data_set,target_bandwidth):
            std_dev = np.std(data_set)
            return target_bandwidth / std_dev  # Compute covariance factor for desired bandwidth
        
        fixed_bandwidth = fixed_bandwidth_method(distances, desired_bandwidth)
        density = gaussian_kde(distances,bw_method=fixed_bandwidth)
        xs = np.linspace(0, distances.max(), 200)
        density_values = density(xs)
        # Find the x-value where the density is highest
        # Calculate the mean of the data
        peak_index = np.argmax(density_values)
        #density_values = density_values/density_values[peak_index]
        #mean_value = np.mean(density_values)

        # Find the index of the element closest to the mean
        #peak_index = np.argmin(np.abs(density_values - mean_value))
        peak_x = xs[peak_index]
        # Plot the density function
        plt.rc('xtick',labelsize=24)
        plt.rc('ytick',labelsize=24)
        plt.plot(xs, density_values, linewidth=4.5, color=colors[i % len(colors)], label=f'{config}')
        # Add vertical dashed line at peak density
        #plt.axvline(x=peak_x, linewidth=4.5, color=colors[i % len(colors)], linestyle='--')
        plt.xlim(1.25,None)
        plt.ylim(None,2.5)
        plt.grid(True,axis='both',which='minor',linestyle='--', alpha=0.5,linewidth=7.5,zorder=1)
        plt.legend(loc="center left", prop={'size': 28})
        plt.annotate(r'$|q| = 0.7830$,'+'\n'+'$d_{ICC} = 10.78 \, \AA$', xy=(0.715, 0.85), xycoords='axes fraction', 
                     fontsize=14, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
        plt.grid(True, axis='both', which='minor', linestyle='--', alpha=0.5, linewidth=3.5, zorder=1)
        plt.grid(True, axis='both', which='major', linestyle='--', alpha=0.25, linewidth=2.75, zorder=1)
        area = np.trapz(density_values, xs)  # Trapezoidal rule for integration
        print("Total area under the KDE curve:", area)
        #plt.grid(True,axis='both',which='major',linestyle='-', alpha=0.5,linewidth=2.75,zorder=1)
    else:
        print(f"No distances to plot for configuration {config}.")

#plt.xlabel('Oxygen-Center of Mass Distance (Å)',fontsize=24)
plt.xlabel(r'$d_{COM_{i}-O_{ij}}$ (Å)',fontsize=24)
#plt.ylabel('Probability Density',fontsize=24)
plt.ylabel('$p(d_{COM_{i}-O_{ij}})$',fontsize=24)
#plt.title('Oxygen-COM Distance Probability Functions',fontsize=28)
plt.legend(prop={'size': 16})
plt.show()
# Out:
# <>:40: SyntaxWarning: invalid escape sequence '\,'
# <>:40: SyntaxWarning: invalid escape sequence '\,'
# /var/folders/ys/y877k0vd3bj8jdjg6z66dk980000gn/T/ipykernel_16494/3714383459.py:40: SyntaxWarning: invalid escape sequence '\,'
#   plt.annotate(r'$|q| = 0.7830$,'+'\n'+'$d_{ICC} = 10.78 \, \AA$', xy=(0.715, 0.85), xycoords='axes fraction',
# Total area under the KDE curve: 0.985904088319179
# Total area under the KDE curve: 0.9863522215175848
# Total area under the KDE curve: 0.9204283742176473
# Total area under the KDE curve: 0.9880935545735844
# Total area under the KDE curve: 0.9258509941245707

# %%
# Plotting Layer COM Distance Probability Functions for all configurations
plt.figure(dpi=800)
for i, (config, distances) in enumerate(layer_com_distances_data.items()):
    if distances:
        distances = np.array(distances)
        # Compute probability density
        desired_bandwidth = 1/8

        # Custom bandwidth method
        def fixed_bandwidth_method(data_set,target_bandwidth):
            std_dev = np.std(data_set)
            return target_bandwidth / std_dev  # Compute covariance factor for desired bandwidth
        
        fixed_bandwidth = fixed_bandwidth_method(distances, desired_bandwidth)
        density = gaussian_kde(distances,bw_method=fixed_bandwidth)
        xs = np.linspace(0, distances.max(), 200)
        density_values = density(xs)
        # Find the x-value where the density is highest
        #peak_index = np.argmax(density_values)
        peak_index = np.argmax(density_values)
        #density_values = density_values/density_values[peak_index]
        peak_x = xs[peak_index]
        # Plot the density function
        plt.plot(xs, density_values, linewidth=4.5, color=colors[i % len(colors)], label=f'{config}')
        plt.legend(loc="center left", prop={'size': 28})
        plt.annotate(r'$|q| = 0.7830$,'+'\n'+'$d_{ICC} = 10.78 \, \AA$', xy=(0.715, 0.85), xycoords='axes fraction', 
                     fontsize=14, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
        plt.grid(True, axis='both', which='minor', linestyle='--', alpha=0.5, linewidth=3.5, zorder=1)
        plt.grid(True, axis='both', which='major', linestyle='--', alpha=0.25, linewidth=2.75, zorder=1)
 
        # Add vertical dashed line at peak density
        #plt.axvline(x=peak_x, linewidth=4.5, color=colors[i % len(colors)], linestyle='--')
        plt.xlim(2.2,None)
    else:
        print(f"No COM distances to plot for configuration {config}.")

#plt.xlabel('Distance Between Adjacent Layer COMs (Å)',fontsize=24)
plt.xlabel(r'$d_{COM_{i}-COM_{j}}$ (adjacent only) (Å)',fontsize=24)
plt.ylabel('$p(d_{COM_{i}-COM_{j}})$',fontsize=24)
plt.xlim(2.25,None)
#plt.ylabel('Probability Density',fontsize=24)
#plt.title('Layer to Layer COM Distance Probability Functions')
plt.legend(loc='best',prop={'size': 16})
plt.show()
# Out:
# <>:26: SyntaxWarning: invalid escape sequence '\,'
# <>:26: SyntaxWarning: invalid escape sequence '\,'
# /var/folders/ys/y877k0vd3bj8jdjg6z66dk980000gn/T/ipykernel_16124/607991905.py:26: SyntaxWarning: invalid escape sequence '\,'
#   plt.annotate(r'$|q| = 0.7830$,'+'\n'+'$d_{ICC} = 10.78 \, \AA$', xy=(0.715, 0.85), xycoords='axes fraction',
